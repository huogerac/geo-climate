# %%
import pandas as pd

csv_url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vTTo2JeAZm0NI2-ct-_qaH-lmDFaV77cmGAqY_rYwnClJGaFYkcLUZHVQ06UF2u_aRQ_BK3vZGkVLQ5/pub?gid=524884482&single=true&output=csv'

# %%
df = pd.read_csv(csv_url)

# %% [markdown]
# ## The companies commited to climate change list

# %%
df
# Out:
#                              Company name            ISIN  \
# 0                     AcBel Polytech Inc.    TW0006282007
# 1                     AcBel Polytech Inc.    TW0006282007
# 2                          Chalhoub Group             NaN
# 3                          Chalhoub Group             NaN
# 4            Citrosuco Agroindustria S.A.  Not applicable
# ...                                   ...             ...
# 11713  GALVANICA FORMELLI SRL E MAGUI SRL             NaN
# 11714                     ZETA CATENE SRL             NaN
# 11715           EIKODO HOLDINGS Co., Ltd.             NaN
# 11716                         N3 Group AS             NaN
# 11717                       Technetix Ltd             NaN
#
#                         LEI                   Location  \
# 0      254900BQVM5V0IY7RQ62  Taiwan, Province of China
# 1      254900BQVM5V0IY7RQ62  Taiwan, Province of China
# 2                       NaN       United Arab Emirates
# ...

# %%
companies_by_regions = df['Region '].value_counts()
companies_by_regions
# Out:
# Region
# Europe                             6791
# Asia                               2541
# Northern America                   1718
# Latin America and the Caribbean     273
# Oceania                             258
# Africa                               97
# MENA                                 39
# Name: count, dtype: int64

# %%
companies_by_locations = df['Location'].value_counts()
companies_by_locations
# Out:
# Location
# United Kingdom              2166
# United States of America    1510
# Japan                       1012
# Germany                      671
# France                       667
#                             ...
# Croatia                        1
# Albania                        1
# Nigeria                        1
# Macau, Province of China       1
# Lebanon                        1
# Name: count, Length: 88, dtype: int64

# %% [markdown]
# ## Question
#
# How could we get some geolocation based on the Location and Region. In this way we could plot all companies in map in a way we could visualize all commitments in the globe, perhaps we could see which regions have more companies.
